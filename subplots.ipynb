# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.subplot(1,2,2)
linear_data=np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(1,2,1)
plt.plot(left,'-o')
plt.subplot(1,2,2)
plt.plot(right,'-or')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(2,2,1)
plt.plot(left,'-o')
plt.subplot(2,2,2)
plt.plot(right,'-or')
plt.subplot(2,2,3)
plt.plot(np.array([8,5,2]),'-og')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-o')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True,sharey=True)
ax5.plot(left,'-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-d48cd47124de> in <module>
#       2 linear_data=np.array([10,20,30,40])
#       3 xvals=range(len(linear_data))
# ----> 4 plt.hbar(xvals,linear_data,width=0.3)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'hbar'

# %%
plt.figure()
linear_data=np.array([10,20,30,40,10,10])
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 6 artists>

# %%
marks=[50,50,70,50,90,50,20,50]
plt.figure()
plt.hist(marks)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1., 0., 0., 0., 5., 0., 0., 1., 0., 1.]),
#  array([20., 27., 34., 41., 48., 55., 62., 69., 76., 83., 90.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # box and whisker plot

# %%
height_men=[4,5,6,7,4.5,]

# %%
plt.figure()
a=plt.boxplot(height_men,whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # animations

# %%
import matplotlib.animation as animation
n=100
x=np.random.randn(n)
x
# Out:
# array([-0.35896914,  1.0029482 ,  0.57310087,  1.78652627,  0.25412563,
#         0.88274598,  1.35084848,  2.69625051, -0.14753727,  0.33538647,
#        -1.46634461, -0.35527569, -0.02096751,  2.52760179,  1.90363945,
#         0.55564463,  1.22828158, -1.27035845,  0.02654113, -1.81379632,
#         0.11018083,  0.63037368,  0.23859318,  0.68421126,  0.33377496,
#         0.40150996,  2.01621606, -0.42335561, -1.18358178,  0.38153308,
#        -1.68677451,  0.01467268,  1.33764037, -1.5952184 , -0.90434251,
#         1.22004607, -1.42319695, -1.88590384,  0.20555795,  1.11166282,
#         0.3884154 ,  0.81045589,  0.5386953 ,  0.42293832, -0.01317439,
#         1.23481826,  0.11519104, -1.40402348,  0.76655817,  2.04084242,
#         2.45941026, -0.58637822,  1.58700713,  1.01801975, -0.97453156,
#         1.12043206,  0.89093047, -0.64398976, -1.86572463,  0.47957309,
#        -0.46659173,  0.20196568, -2.02663944,  0.95855911,  0.52963779,
# ...

# %%
def update(curr):
    if curr==n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('samplingthe normal distribution')
    plt.gca().set_ylabel('frequency')
    plt.gca().set_xlabel('value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig,update,interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # interactivity

# %%
plt.figure()
data=np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} \nand data {},{}'.format(event.x,event.y,event.xdata,event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event',onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 6

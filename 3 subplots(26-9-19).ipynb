# %% [markdown]
# ### matplotlib notebook

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1,2,2)
linear_data=np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data,'-o')

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(2,2,1)
plt.plot(left,'-o')
plt.subplot(2,2,2)
plt.plot(right,'-o')
plt.subplot(2,2,3)
plt.plot(np.array([10,11]),'-o')

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-0')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-x')

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True,sharey=True)
ax5.plot(linear_data,'-')

# %%
plt.figure()
linear_data=np.array([10,20,30,40,10,10])
xvals= range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.barh(xvals,linear_data,height=0.3)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### histograms

# %%
marks=[50,60,70,50,50,30,50,70,50]
plt.figure()
plt.hist(marks)
# Out:
# (array([1., 0., 0., 0., 0., 5., 0., 1., 0., 2.]),
#  array([30., 34., 38., 42., 46., 50., 54., 58., 62., 66., 70.]),
#  <a list of 10 Patch objects>)

# %%
hieght_men_at_20=[4,5,4.5,5,6,7]

# %%
plt.figure()
_=plt.boxplot(hieght_men_at_20,whis='range')

# %% [markdown]
# ## Animations

# %%
import matplotlib.animation as animation
n=100
x=np.random.randn(n)
x
# Out:
# array([-0.15235504, -1.40285779,  1.30281842, -1.18830666, -1.07846355,
#         1.84564668, -0.65560031, -0.24296582,  0.7863061 ,  0.78129679,
#        -0.28028468,  0.24590988,  0.82501368,  1.79478765,  1.51285662,
#         2.29885265, -0.76902202,  0.31859778, -0.4208583 , -0.07159639,
#         0.11533203,  0.01887829,  1.30900956,  0.3000585 ,  0.44357586,
#         2.09778291, -0.66674918, -1.07157298,  1.30655758, -2.08033193,
#         1.00669011, -0.41258938, -0.1495615 , -0.79935525,  1.22708066,
#        -3.71351544, -1.03940179,  0.17761252, -0.06125355,  0.43434873,
#         0.23531087, -0.10859292, -0.51439647,  0.01885655, -0.6676991 ,
#         0.44953804, -0.9532366 , -0.42179464,  3.27437104, -1.40074193,
#         0.80717714, -0.22688945,  0.49388989, -0.1574709 , -0.3996135 ,
#         0.39109521,  0.99250085,  2.27663619,  1.85278884, -1.45241036,
#         0.06574813, -1.29103798, -0.73690766, -1.11884007, -0.79666684,
#         0.29259782, -0.88394501, -1.27039292, -1.43045331, -1.38825699,
#        -0.81370776, -0.51394508,  0.11160802,  1.14330692, -0.06386537,
#         0.70984231,  1.65821884, -1.31921279, -0.5644035 ,  1.15059771,
#        -0.37668401, -0.52797705, -1.53628128,  0.1089184 , -0.042578  ,
#        -1.43032426,  0.30867083,  0.68807739,  0.44305547, -0.34630152,
#        -0.62712536,  0.32380415,  0.43134139, -1.31865482, -0.0220848 ,
#         0.67898387, -0.67004809,  0.54213435, -0.29990316, -0.62282256])

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig,update,interval=100)
# Out:
# <img src="data:image/png;base64,..." width="895.0000152417594">

# %% [markdown]
# ## INTERACTIVITY

# %%
plt.figure()
data=np.random.rand(10)
plt.plot(data)
def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title(
        'Event at pixes {},{} \nand data{},{}'.format(event.x,event.y.event.xdata.event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event',onclick)
# Out:
# <img src="data:image/png;base64,..." width="895.0000152417594">
# 6
